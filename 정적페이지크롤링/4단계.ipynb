# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 11.0/11.0 MB 55.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------------- -------------------------- 4.5/12.8 MB 22.4 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 32.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 28.3 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
# ...

# %%
pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
#1. 엑셀 파일에 데이터 저장
import requests
from bs4 import BeautifulSoup
import pandas as pd

#search = input("검색어를 입력하세요.")
data = []

for i in range(3,4):
    #주소 요청
    #response = requests.get(f"https://startcoding.pythonanywhere.com/basic?page={i}&keyword={search}")
    response = requests.get(f"https://startcoding.pythonanywhere.com/basic?page={i}")

    #통신 상태 코드
    #print(response.status_code)

    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    items = soup.select(".product")

    for item in items:
        category = item.select_one(".product-category").text
        name = item.select_one(".product-name").text
        link = item.select_one(".product-name > a").attrs['href']
        price = item.select_one(".product-price").text.split('원')[0].replace(',', '')

        #print(category, name, link, price)
        data.append([category, name, link, price])

df = pd.DataFrame(data, columns=['카테고리', '상품명', '상세페이지링크', '가격'])
#df.to_excel('result.xlsx', index=False)


#2. 파일에 이어서 저장

#기존 엑셀 파일 불러오기
#existing_df = pd.read_excel('result.xlsx')

#기존 데이터프레임에 새로운 데이터 추가
#updated_df = pd.concat([existing_df, df], ignore_index=True)

#엑셀 저장
#updated_df.to_excel('result.xlsx', index=False)


#3. 새로운 시트에 저장


#ExcelWriter를 사용하여 기존 엑셀 파일 열기
with pd.ExcelWriter('result.xlsx', mode='a', engine='openpyxl') as writer:
    #새로운 시트에 저장
    df.to_excel(writer, sheet_name='휴대폰', index=False)
